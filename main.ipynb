# %% [markdown]
# ## Setup Code

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a HAPPYSNAKE folder and put all the files under SADSNAKE folder, then 'HAPPYSNAKE/SADSNAKE'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'newSnakeRL'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['LICENSE', 'main.py', 'README.md', 'common', 'game', 'pngs', 'agent', 'model', '.git', 'main']

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os

# %% [markdown]
# ## Main Code

# %%
import torch

from common.settings import *
from agent.play_game_with_agent import *
from agent.dqn_agent import DQNAgent
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def main():
    """
    Start
    │
    └─── Choose mode
        │
        ├─── Play
        │   │
        │   └─── Load previous model
        │       │
        │       ├─── Success
        │       │   └─── Play with loaded model
        │       │
        │       └─── Fail
        │           │
        │           └─── Continue without loaded model?
        │               │
        │               ├─── Yes
        │               │   └─── Play with untrained model
        │               │
        │               └─── No
        │                   └─── Return to mode selection
        │
        └─── Learn and Play
            │
            └─── Start training from scratch?
                │
                ├─── Yes
                │   └─── Start new training
                │
                └─── No
                    │
                    └─── Load previous model
                        │
                        ├─── Success
                        │   └─── Play and learn with loaded model
                        │
                        └─── Fail
                            │
                            └─── Continue without loaded model?
                                │
                                ├─── Yes
                                │   └─── Play and learn with untrained model
                                │
                                └─── No
                                    └─── Return to mode selection
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    # dqn_agent
    dqn_agent = DQNAgent(device=device)
    while True:
        user_input = input("Choose mode: (a) Play or (b) Learn and Play (a/b): ").lower()
        if user_input in ['a', 'play']:
            print("Play mode selected.")
            if play_mode(dqn_agent):
                break
        elif user_input in ['b', 'learn and play']:
            # create a callback function to update the figure dynamically
            update_plot = create_training_plotter()
            
            print("Learn and Play mode selected.")
            if learn_and_play_mode(dqn_agent, update_plot):
                break
        else:
            print("Invalid input. Please enter 'a' for Play or 'b' for Learn and Play.")

def play_mode(dqn_agent: DQNAgent):
    """
    Return True if agent starts playing else False.
    """
    if load_model(dqn_agent):
        print("Previous model loaded successfully.")
        play_with_agent(dqn_agent, 
                        playing_rounds_per_display=playing_rounds_per_display, 
                        total_rounds=playing_total_rounds)
        return True
    else:
        prompt = "Without loaded weights, the agent's performance will be poor. Continue? (y/n): "
        if confirm_action(prompt):
            print("Continuing with untrained agent...")
            play_with_agent(dqn_agent, 
                            playing_rounds_per_display=playing_rounds_per_display, 
                            total_rounds=playing_total_rounds)
            return True
        else:
            print("Returning to mode selection...")
            return False

def learn_and_play_mode(dqn_agent: DQNAgent, update_plot):
    """
    Return True if agent starts learning and playing else False.
    """
    if not confirm_action("Start training from scratch? (y/n): "):
        print("Attempting to load previous model...")
        if load_model(dqn_agent):
            print("Previous model loaded successfully.")
        else:
            print("Failed to load previous model.")
            if not confirm_action("Continue with untrained model? (y/n): "):
                print("Returning to mode selection...")
                return False
    
    print("Starting training...")
    play_and_learn_with_learning_agent(dqn_agent, 
                                       total_episodes=learning_total_episodes, 
                                       update_plot_callback=update_plot, 
                                       learning_episodes_per_display=learning_episodes_per_display)
    return True

def load_model(dqn_agent: DQNAgent):
    """
    Load both main and target models.
    Return True if loaded successfully else False.
    """
    if dqn_agent.load():
        return True
    else:
        return False

def confirm_action(prompt: str):
    """
    If player input 'y' then return True, if input 'n' then return False, else loop.
    """
    while True:
        user_input = input(prompt).lower()
        if user_input in ['y', 'n']:
            return user_input == 'y'
        print("Invalid input. Please enter 'y' or 'n'.")

# %%
if __name__ == "__main__":
    main()
# Out:
# Agent initialized on device: cuda
# Choose mode: (a) Play or (b) Learn and Play (a/b): b
# Learn and Play mode selected.
# Start training from scratch? (y/n): y
# Starting training from scratch...
# Play times: 1, Score: 1
# Epsilon: 0.7990000000000002
# Average loss: 1548.005615234375
# Average score current 100 rounds: 1.0
#
#
# Play times: 2, Score: 0
# Epsilon: 0.7954000000000006
# Average loss: 304.57593705919055
# Average score current 100 rounds: 0.5
#
#
# Play times: 3, Score: 0
# Epsilon: 0.7946000000000006
# Average loss: 316.0437240600586
# Average score current 100 rounds: 0.3333333333333333
#
#
# Play times: 4, Score: 0
# Epsilon: 0.7838000000000018
# Average loss: 114.0982185293127
# Average score current 100 rounds: 0.25
#
#
# Play times: 5, Score: 0
# Epsilon: 0.773600000000003
# Average loss: 32.803807800891356
# Average score current 100 rounds: 0.2
#
#
# Play times: 6, Score: 0
# Epsilon: 0.7652000000000039
# Average loss: 27.68225241842724
# Average score current 100 rounds: 0.16666666666666666
#
#
# Play times: 7, Score: 0
# Epsilon: 0.7626000000000042
# Average loss: 20.0608643751878
# Average score current 100 rounds: 0.14285714285714285
#
#
# Play times: 8, Score: 0
# Epsilon: 0.7588000000000046
# Average loss: 78.27832442835758
# Average score current 100 rounds: 0.125
#
#
# Play times: 9, Score: 0
# Epsilon: 0.754800000000005
# Average loss: 26.843431377410887
# Average score current 100 rounds: 0.1111111111111111
#
#
# Play times: 10, Score: 1
# Epsilon: 0.7488000000000057
# Average loss: 95.07589667638143
# Average score current 100 rounds: 0.2
#
#
# Play times: 11, Score: 1
# Epsilon: 0.737200000000007
# Average loss: 34.98261568464082
# Average score current 100 rounds: 0.2727272727272727
#
#
# Play times: 12, Score: 0
# Epsilon: 0.7290000000000079
# Average loss: 22.78063501962801
# Average score current 100 rounds: 0.25
#
#
# Play times: 13, Score: 0
# Epsilon: 0.7124000000000097
# Average loss: 15.944727093340402
# Average score current 100 rounds: 0.23076923076923078
#
#
# Play times: 14, Score: 0
# Epsilon: 0.70980000000001
# Average loss: 21.165020502530613
# Average score current 100 rounds: 0.21428571428571427
#
#
# Play times: 15, Score: 0
# Epsilon: 0.7032000000000107
# Average loss: 29.61282156452988
# Average score current 100 rounds: 0.2
#
#
# Play times: 16, Score: 0
# Epsilon: 0.6938000000000117
# Average loss: 30.02905397212252
# Average score current 100 rounds: 0.1875
#
#
# Play times: 17, Score: 1
# Epsilon: 0.6886000000000123
# Average loss: 41.38903093338013
# Average score current 100 rounds: 0.23529411764705882
#
#
# Play times: 18, Score: 0
# Epsilon: 0.6866000000000125
# Average loss: 36.97526378631592
# Average score current 100 rounds: 0.2222222222222222
#
#
# Play times: 19, Score: 0
# Epsilon: 0.682400000000013
# Average loss: 26.309365499587287
# Average score current 100 rounds: 0.21052631578947367
#
#
# Play times: 20, Score: 0
# Epsilon: 0.6770000000000136
# Average loss: 22.389932561803747
# Average score current 100 rounds: 0.2
#
#
# Play times: 21, Score: 0
# Epsilon: 0.6738000000000139
# Average loss: 26.094662755727768
# Average score current 100 rounds: 0.19047619047619047
#
#
# Play times: 22, Score: 0
# Epsilon: 0.673000000000014
# Average loss: 24.47803556919098
# Average score current 100 rounds: 0.18181818181818182
#
#
# Play times: 23, Score: 0
# Epsilon: 0.6714000000000142
# Average loss: 16.48932546377182
# Average score current 100 rounds: 0.17391304347826086
#
#
# Play times: 24, Score: 1
# Epsilon: 0.6666000000000147
# Average loss: 29.73814042409261
# Average score current 100 rounds: 0.20833333333333334
#
#
# Play times: 25, Score: 0
# Epsilon: 0.6630000000000151
# Average loss: 22.216063658396404
# Average score current 100 rounds: 0.2
#
#
# Play times: 26, Score: 0
# Epsilon: 0.6584000000000156
# Average loss: 39.01826000213623
# Average score current 100 rounds: 0.19230769230769232
#
#
# Play times: 27, Score: 0
# Epsilon: 0.6526000000000163
# Average loss: 29.618353876574286
# Average score current 100 rounds: 0.18518518518518517
#
#
# Play times: 28, Score: 1
# Epsilon: 0.6506000000000165
# Average loss: 25.28493528366089
# Average score current 100 rounds: 0.21428571428571427
#
#
# Play times: 29, Score: 0
# Epsilon: 0.6466000000000169
# Average loss: 22.847757482528685
# Average score current 100 rounds: 0.20689655172413793
#
#
# Play times: 30, Score: 0
# Epsilon: 0.6442000000000172
# Average loss: 19.026736338933308
# Average score current 100 rounds: 0.2
#
#
# Play times: 31, Score: 0
# Epsilon: 0.6414000000000175
# Average loss: 65.73470551627022
# Average score current 100 rounds: 0.1935483870967742
#
#
# Play times: 32, Score: 0
# Epsilon: 0.6388000000000178
# Average loss: 15.406067921565128
# Average score current 100 rounds: 0.1875
#
#
# Play times: 33, Score: 0
# Epsilon: 0.6352000000000182
# Average loss: 17.889466418160332
# Average score current 100 rounds: 0.18181818181818182
#
#
# Play times: 34, Score: 0
# Epsilon: 0.6326000000000185
# Average loss: 11.110111640049862
# Average score current 100 rounds: 0.17647058823529413
#
#
# Play times: 35, Score: 0
# Epsilon: 0.6296000000000188
# Average loss: 31.19969310760498
# Average score current 100 rounds: 0.17142857142857143
#
#
# Play times: 36, Score: 0
# Epsilon: 0.6236000000000195
# Average loss: 36.625773970286055
# Average score current 100 rounds: 0.16666666666666666
#
#
# Play times: 37, Score: 0
# Epsilon: 0.6210000000000198
# Average loss: 35.85504883986253
# Average score current 100 rounds: 0.16216216216216217
#
#
# Play times: 38, Score: 0
# Epsilon: 0.6144000000000205
# Average loss: 21.841342998273443
# Average score current 100 rounds: 0.15789473684210525
#
#
# Play times: 39, Score: 1
# Epsilon: 0.6116000000000208
# Average loss: 35.11981977735247
# Average score current 100 rounds: 0.1794871794871795
#
#
# Play times: 40, Score: 0
# Epsilon: 0.6104000000000209
# Average loss: 20.041282733281452
# Average score current 100 rounds: 0.175
#
#
# Play times: 41, Score: 0
# Epsilon: 0.6074000000000213
# Average loss: 29.398006629943847
# Average score current 100 rounds: 0.17073170731707318
#
#
# Play times: 42, Score: 0
# Epsilon: 0.6044000000000216
# Average loss: 26.13573080698649
# Average score current 100 rounds: 0.16666666666666666
#
#
# Play times: 43, Score: 0
# Epsilon: 0.6022000000000218
# Average loss: 18.044949531555176
# Average score current 100 rounds: 0.16279069767441862
#
#
# Play times: 44, Score: 0
# Epsilon: 0.5996000000000221
# Average loss: 20.176921844482422
# Average score current 100 rounds: 0.1590909090909091
#
#
# Play times: 45, Score: 0
# Epsilon: 0.5960000000000225
# Average loss: 18.809516535864937
# Average score current 100 rounds: 0.15555555555555556
#
#
# Play times: 46, Score: 1
# Epsilon: 0.5946000000000227
# Average loss: 11.828232084001813
# Average score current 100 rounds: 0.17391304347826086
#
#
# Play times: 47, Score: 0
# Epsilon: 0.592000000000023
# Average loss: 62.79380314166729
# Average score current 100 rounds: 0.1702127659574468
#
#
# Play times: 48, Score: 0
# Epsilon: 0.5880000000000234
# Average loss: 28.336712074279784
# Average score current 100 rounds: 0.16666666666666666
#
#
# Play times: 49, Score: 0
# Epsilon: 0.5872000000000235
# Average loss: 22.17297351360321
# Average score current 100 rounds: 0.16326530612244897
#
#
# Model saved to /content/drive/My Drive/newSnakeRL/model/weights/linear_dqn_model.pth
# Feel free to press Ctrl+C to terminate the program or close the window
# Play times: 50, Score: 0
# Epsilon: 0.582200000000024
# Average loss: 28.73891990661621
# Average score current 100 rounds: 0.16
#
#
# Play times: 51, Score: 0
# Epsilon: 0.5804000000000242
# Average loss: 25.862800492180718
# Average score current 100 rounds: 0.1568627450980392
#
#
# Play times: 52, Score: 0
# Epsilon: 0.5792000000000244
# Average loss: 54.11466630299886
# Average score current 100 rounds: 0.15384615384615385
#
#
# Play times: 53, Score: 1
# Epsilon: 0.573200000000025
# Average loss: 22.701747989654542
# Average score current 100 rounds: 0.16981132075471697
#
#
# Play times: 54, Score: 0
# Epsilon: 0.5724000000000251
# Average loss: 21.011897325515747
# Average score current 100 rounds: 0.16666666666666666
#
#
# Play times: 55, Score: 0
# Epsilon: 0.5652000000000259
# Average loss: 23.87211865848965
# Average score current 100 rounds: 0.16363636363636364
#
#
# Play times: 56, Score: 0
# Epsilon: 0.5606000000000264
# Average loss: 20.83505520613297
# Average score current 100 rounds: 0.16071428571428573
#
#
# Play times: 57, Score: 0
# Epsilon: 0.554800000000027
# Average loss: 28.965033037909144
# Average score current 100 rounds: 0.15789473684210525
#
#
# Play times: 58, Score: 1
# Epsilon: 0.5504000000000275
# Average loss: 36.21275225552645
# Average score current 100 rounds: 0.1724137931034483
#
#
# Play times: 59, Score: 0
# Epsilon: 0.5488000000000277
# Average loss: 36.590919852256775
# Average score current 100 rounds: 0.1694915254237288
#
#
# Play times: 60, Score: 0
# Epsilon: 0.5468000000000279
# Average loss: 17.868507385253906
# Average score current 100 rounds: 0.16666666666666666
#
#
# Play times: 61, Score: 0
# Epsilon: 0.5438000000000283
# Average loss: 20.87954444885254
# Average score current 100 rounds: 0.16393442622950818
#
#
# Play times: 62, Score: 0
# Epsilon: 0.5412000000000285
# Average loss: 31.27049152667706
# Average score current 100 rounds: 0.16129032258064516
#
#
# Play times: 63, Score: 0
# Epsilon: 0.5388000000000288
# Average loss: 32.01658868789673
# Average score current 100 rounds: 0.15873015873015872
#
#
# Play times: 64, Score: 0
# Epsilon: 0.537000000000029
# Average loss: 71.15932263268365
# Average score current 100 rounds: 0.15625
#
#
# Play times: 65, Score: 0
# Epsilon: 0.5352000000000292
# Average loss: 17.716936853196884
# Average score current 100 rounds: 0.15384615384615385
#
#
# Play times: 66, Score: 0
# Epsilon: 0.5322000000000295
# Average loss: 15.231435712178548
# Average score current 100 rounds: 0.15151515151515152
#
#
# Play times: 67, Score: 0
# Epsilon: 0.5270000000000301
# Average loss: 17.15337610244751
# Average score current 100 rounds: 0.14925373134328357
#
#
# Play times: 68, Score: 0
# Epsilon: 0.5254000000000303
# Average loss: 8.97865891456604
# Average score current 100 rounds: 0.14705882352941177
#
#
# Play times: 69, Score: 0
# Epsilon: 0.5222000000000306
# Average loss: 21.849412322044373
# Average score current 100 rounds: 0.14492753623188406
#
#
# Play times: 70, Score: 0
# Epsilon: 0.519000000000031
# Average loss: 64.82467794418335
# Average score current 100 rounds: 0.14285714285714285
#
#
# Play times: 71, Score: 0
# Epsilon: 0.5126000000000317
# Average loss: 17.158162266016006
# Average score current 100 rounds: 0.14084507042253522
#
#
# Play times: 72, Score: 0
# Epsilon: 0.509800000000032
# Average loss: 26.265532663890294
# Average score current 100 rounds: 0.1388888888888889
#
#
# Play times: 73, Score: 2
# Epsilon: 0.5062000000000324
# Average loss: 30.423022482130264
# Average score current 100 rounds: 0.1643835616438356
#
#
# Play times: 74, Score: 0
# Epsilon: 0.5040000000000326
# Average loss: 29.98779114809903
# Average score current 100 rounds: 0.16216216216216217
#
#
# Play times: 75, Score: 0
# Epsilon: 0.500400000000033
# Average loss: 67.24717834260728
# Average score current 100 rounds: 0.16
#
#
# Play times: 76, Score: 0
# Epsilon: 0.4954000000000336
# Average loss: 61.133832397460935
# Average score current 100 rounds: 0.15789473684210525
#
#
# Play times: 77, Score: 0
# Epsilon: 0.4934000000000338
# Average loss: 50.33897180557251
# Average score current 100 rounds: 0.15584415584415584
#
#
# Play times: 78, Score: 0
# Epsilon: 0.4908000000000341
# Average loss: 19.19834379049448
# Average score current 100 rounds: 0.15384615384615385
#
#
# Play times: 79, Score: 0
# Epsilon: 0.48860000000003434
# Average loss: 13.126812501387162
# Average score current 100 rounds: 0.1518987341772152
#
#
# Play times: 80, Score: 0
# Epsilon: 0.4780000000000355
# Average loss: 25.03129551545629
# Average score current 100 rounds: 0.15
#
#
# Play times: 81, Score: 0
# Epsilon: 0.4724000000000361
# Average loss: 36.627120631081716
# Average score current 100 rounds: 0.14814814814814814
#
#
# Play times: 82, Score: 0
# Epsilon: 0.46960000000003643
# Average loss: 34.78916583742414
# Average score current 100 rounds: 0.14634146341463414
#
#
# Play times: 83, Score: 0
# Epsilon: 0.4680000000000366
# Average loss: 11.805420756340027
# Average score current 100 rounds: 0.14457831325301204
#
#
# Play times: 84, Score: 0
# Epsilon: 0.46380000000003707
# Average loss: 28.03705092838832
# Average score current 100 rounds: 0.14285714285714285
#
#
# Play times: 85, Score: 0
# Epsilon: 0.4588000000000376
# Average loss: 14.346585731506348
# Average score current 100 rounds: 0.1411764705882353
#
#
# Play times: 86, Score: 0
# Epsilon: 0.45680000000003784
# Average loss: 25.893525075912475
# Average score current 100 rounds: 0.13953488372093023
#
#
# Play times: 87, Score: 1
# Epsilon: 0.45400000000003815
# Average loss: 32.503012316567556
# Average score current 100 rounds: 0.14942528735632185
#
#
# Play times: 88, Score: 0
# Epsilon: 0.44860000000003875
# Average loss: 16.670712241420038
# Average score current 100 rounds: 0.14772727272727273
#
#
# Play times: 89, Score: 0
# Epsilon: 0.446400000000039
# Average loss: 29.291117321361195
# Average score current 100 rounds: 0.14606741573033707
#
#
# Play times: 90, Score: 1
# Epsilon: 0.44220000000003945
# Average loss: 14.37368206750779
# Average score current 100 rounds: 0.15555555555555556
#
#
# Play times: 91, Score: 0
# Epsilon: 0.43940000000003976
# Average loss: 14.843019740922111
# Average score current 100 rounds: 0.15384615384615385
#
#
# Play times: 92, Score: 0
# Epsilon: 0.43720000000004
# Average loss: 16.7091458494013
# Average score current 100 rounds: 0.15217391304347827
#
#
# Play times: 93, Score: 0
# Epsilon: 0.43400000000004035
# Average loss: 13.710645407438278
# Average score current 100 rounds: 0.15053763440860216
#
#
# Play times: 94, Score: 0
# Epsilon: 0.43220000000004055
# Average loss: 17.398919847276474
# Average score current 100 rounds: 0.14893617021276595
#
#
# Play times: 95, Score: 0
# Epsilon: 0.43060000000004073
# Average loss: 17.891677021980286
# Average score current 100 rounds: 0.14736842105263157
#
#
# Play times: 96, Score: 0
# Epsilon: 0.42680000000004115
# Average loss: 14.47003113596063
# Average score current 100 rounds: 0.14583333333333334
#
#
# Play times: 97, Score: 0
# Epsilon: 0.42500000000004134
# Average loss: 12.210034635331896
# Average score current 100 rounds: 0.14432989690721648
#
#
# Play times: 98, Score: 0
# Epsilon: 0.4218000000000417
# Average loss: 11.318074315786362
# Average score current 100 rounds: 0.14285714285714285
#
#
# Play times: 99, Score: 0
# Epsilon: 0.4182000000000421
# Average loss: 10.845369286007351
# Average score current 100 rounds: 0.1414141414141414
#
#
# Model saved to /content/drive/My Drive/newSnakeRL/model/weights/linear_dqn_model.pth
# Feel free to press Ctrl+C to terminate the program or close the window
# Play times: 100, Score: 0
# Epsilon: 0.4154000000000424
# Average loss: 8.699955344200134
# Average score current 100 rounds: 0.14
#
#
# Play times: 101, Score: 1
# Epsilon: 0.41240000000004273
# Average loss: 14.481179237365723
# Average score current 100 rounds: 0.14
#
#
# Play times: 102, Score: 0
# Epsilon: 0.41060000000004293
# Average loss: 7.445298088921441
# Average score current 100 rounds: 0.14
#
#
# Play times: 103, Score: 0
# Epsilon: 0.4092000000000431
# Average loss: 12.519978250776019
# Average score current 100 rounds: 0.14
#
#
# Play times: 104, Score: 0
# Epsilon: 0.4062000000000434
# Average loss: 10.630510838826497
# Average score current 100 rounds: 0.14
#
#
# Play times: 105, Score: 0
# Epsilon: 0.40480000000004357
# Average loss: 9.691787787846156
# Average score current 100 rounds: 0.14
#
#
# Play times: 106, Score: 0
# Epsilon: 0.40240000000004383
# Average loss: 15.359646479288736
# Average score current 100 rounds: 0.14
#
#
# Play times: 107, Score: 0
# Epsilon: 0.39880000000004423
# Average loss: 15.767004834281074
# Average score current 100 rounds: 0.14
#
#
# Play times: 108, Score: 0
# Epsilon: 0.392000000000045
# Average loss: 14.653061081381406
# Average score current 100 rounds: 0.14
#
#
# Play times: 109, Score: 0
# Epsilon: 0.39040000000004516
# Average loss: 33.206780791282654
# Average score current 100 rounds: 0.14
#
#
# Play times: 110, Score: 0
# Epsilon: 0.38860000000004535
# Average loss: 13.040623346964518
# Average score current 100 rounds: 0.13
#
#
# Play times: 111, Score: 0
# Epsilon: 0.3862000000000456
# Average loss: 36.09984139601389
# Average score current 100 rounds: 0.12
#
#
# Play times: 112, Score: 0
# Epsilon: 0.38120000000004617
# Average loss: 14.348700275421143
# Average score current 100 rounds: 0.12
#
#
# Play times: 113, Score: 0
# Epsilon: 0.37940000000004637
# Average loss: 11.767821788787842
# Average score current 100 rounds: 0.12
#
#
# Play times: 114, Score: 0
# Epsilon: 0.37400000000004696
# Average loss: 8.77640672966286
# Average score current 100 rounds: 0.12
#
#
# Play times: 115, Score: 0
# Epsilon: 0.36760000000004767
# Average loss: 11.495276093482971
# Average score current 100 rounds: 0.12
#
#
# Play times: 116, Score: 0
# Epsilon: 0.36520000000004793
# Average loss: 8.760039607683817
# Average score current 100 rounds: 0.12
#
#
# Play times: 117, Score: 0
# Epsilon: 0.3620000000000483
# Average loss: 14.52406731247902
# Average score current 100 rounds: 0.11
#
#
# Play times: 118, Score: 0
# Epsilon: 0.3598000000000485
# Average loss: 11.492814215746792
# Average score current 100 rounds: 0.11
#
#
# Play times: 119, Score: 0
# Epsilon: 0.35780000000004875
# Average loss: 7.063346433639526
# Average score current 100 rounds: 0.11
#
#
# Play times: 120, Score: 0
# Epsilon: 0.355400000000049
# Average loss: 15.893974224726358
# Average score current 100 rounds: 0.11
#
#
# Play times: 121, Score: 0
# Epsilon: 0.3530000000000493
# Average loss: 14.097729563713074
# Average score current 100 rounds: 0.11
#
#
# Play times: 122, Score: 0
# Epsilon: 0.35160000000004943
# Average loss: 14.67800235748291
# Average score current 100 rounds: 0.11
#
#
# Play times: 123, Score: 0
# Epsilon: 0.34940000000004967
# Average loss: 16.1470063382929
# Average score current 100 rounds: 0.11
#
#
# Play times: 124, Score: 0
# Epsilon: 0.3400000000000507
# Average loss: 11.253283500671387
# Average score current 100 rounds: 0.1
#
#
# Play times: 125, Score: 0
# Epsilon: 0.337400000000051
# Average loss: 17.399435776930588
# Average score current 100 rounds: 0.1
#
#
# Play times: 126, Score: 0
# Epsilon: 0.3364000000000511
# Average loss: 8.270737171173096
# Average score current 100 rounds: 0.1
#
#
# Play times: 127, Score: 0
# Epsilon: 0.3338000000000514
# Average loss: 7.608004404948308
# Average score current 100 rounds: 0.1
#
#
# Play times: 128, Score: 0
# Epsilon: 0.3146000000000535
# Average loss: 9.481507365902266
# Average score current 100 rounds: 0.09
#
#
# Play times: 129, Score: 0
# Epsilon: 0.310000000000054
# Average loss: 5.1994486269743545
# Average score current 100 rounds: 0.09
#
#
# Play times: 130, Score: 0
# Epsilon: 0.30520000000005454
# Average loss: 4.652245283126831
# Average score current 100 rounds: 0.09
#
#
# Play times: 131, Score: 1
# Epsilon: 0.2976000000000554
# Average loss: 51.758753764001945
# Average score current 100 rounds: 0.1
#
#
# Play times: 132, Score: 1
# Epsilon: 0.29340000000005584
# Average loss: 40.23981366838728
# Average score current 100 rounds: 0.11
#
#
# Play times: 133, Score: 0
# Epsilon: 0.28960000000005626
# Average loss: 41.04553712041754
# Average score current 100 rounds: 0.11
#
#
# Play times: 134, Score: 0
# Epsilon: 0.2884000000000564
# Average loss: 189.29526964823404
# Average score current 100 rounds: 0.11
#
#
# Play times: 135, Score: 2
# Epsilon: 0.2840000000000569
# Average loss: 30.914262641559947
# Average score current 100 rounds: 0.13
#
#
# Play times: 136, Score: 1
# Epsilon: 0.2766000000000577
# Average loss: 42.46174135723629
# Average score current 100 rounds: 0.14
#
#
# Play times: 137, Score: 0
# Epsilon: 0.27040000000005837
# Average loss: 51.56246386035796
# Average score current 100 rounds: 0.14
#
#
# Play times: 138, Score: 0
# Epsilon: 0.2664000000000588
# Average loss: 74.47184245586395
# Average score current 100 rounds: 0.14
#
#
# Play times: 139, Score: 0
# Epsilon: 0.2496000000000606
# Average loss: 42.63493135429564
# Average score current 100 rounds: 0.13
#
#
# Play times: 140, Score: 0
# Epsilon: 0.24820000000006057
# Average loss: 13.338035242898124
# Average score current 100 rounds: 0.13
#
#
# Play times: 141, Score: 0
# Epsilon: 0.24460000000006046
# Average loss: 68.77526187896729
# Average score current 100 rounds: 0.13
#
#
# Play times: 142, Score: 0
# Epsilon: 0.23700000000006025
# Average loss: 20.88432509020755
# Average score current 100 rounds: 0.13
#
#
# Play times: 143, Score: 0
# Epsilon: 0.22900000000006002
# Average loss: 47.74572423696518
# Average score current 100 rounds: 0.13
#
#
# Play times: 144, Score: 0
# Epsilon: 0.22660000000005995
# Average loss: 12.367897470792135
# Average score current 100 rounds: 0.13
#
#
# Play times: 145, Score: 0
# Epsilon: 0.22360000000005986
# Average loss: 68.33464867273966
# Average score current 100 rounds: 0.13
#
#
# Play times: 146, Score: 0
# Epsilon: 0.21880000000005972
# Average loss: 13.82897686958313
# Average score current 100 rounds: 0.12
#
#
# Play times: 147, Score: 0
# Epsilon: 0.21500000000005962
# Average loss: 8.459051207492227
# Average score current 100 rounds: 0.12
#
#
# Play times: 148, Score: 0
# Epsilon: 0.21340000000005957
# Average loss: 8.955688774585724
# Average score current 100 rounds: 0.12
#
#
# Play times: 149, Score: 0
# Epsilon: 0.2070000000000594
# Average loss: 19.49241904914379
# Average score current 100 rounds: 0.12
#
#
# Model saved to /content/drive/My Drive/newSnakeRL/model/weights/linear_dqn_model.pth
# Feel free to press Ctrl+C to terminate the program or close the window
# Play times: 150, Score: 0
# Epsilon: 0.20280000000005927
# Average loss: 8.553341275169736
# Average score current 100 rounds: 0.12
#
#
# Play times: 151, Score: 0
# Epsilon: 0.19920000000005916
# Average loss: 11.13364150789049
# Average score current 100 rounds: 0.12
#
#
# Play times: 152, Score: 0
# Epsilon: 0.19780000000005912
# Average loss: 9.750792298998151
# Average score current 100 rounds: 0.12
#
#
# Play times: 153, Score: 0
# Epsilon: 0.1968000000000591
# Average loss: 9.45056381225586
# Average score current 100 rounds: 0.11
#
#
# Play times: 154, Score: 0
# Epsilon: 0.19400000000005901
# Average loss: 7.152134963444301
# Average score current 100 rounds: 0.11
#
#
# Play times: 155, Score: 1
# Epsilon: 0.19080000000005892
# Average loss: 7.106237143278122
# Average score current 100 rounds: 0.12
#
#
# Play times: 156, Score: 0
# Epsilon: 0.1864000000000588
# Average loss: 10.0995426828211
# Average score current 100 rounds: 0.12
#
#
# Play times: 157, Score: 0
# Epsilon: 0.18360000000005872
# Average loss: 7.988925950867789
# Average score current 100 rounds: 0.12
#
#
# Play times: 158, Score: 1
# Epsilon: 0.17420000000005845
# Average loss: 14.738507260667516
# Average score current 100 rounds: 0.12
#
#
# Play times: 159, Score: 0
# Epsilon: 0.1724000000000584
# Average loss: 8.110266314612495
# Average score current 100 rounds: 0.12
#
#
# Play times: 160, Score: 0
# Epsilon: 0.17040000000005834
# Average loss: 31.82164783477783
# Average score current 100 rounds: 0.12
#
#
# Play times: 161, Score: 0
# Epsilon: 0.16720000000005825
# Average loss: 8.79420006275177
# Average score current 100 rounds: 0.12
#
#
# Play times: 162, Score: 0
# Epsilon: 0.1658000000000582
# Average loss: 10.99130003792899
# Average score current 100 rounds: 0.12
#
#
# Play times: 163, Score: 0
# Epsilon: 0.16080000000005806
# Average loss: 16.20780520439148
# Average score current 100 rounds: 0.12
#
#
# Play times: 164, Score: 0
# Epsilon: 0.15780000000005798
# Average loss: 8.117449951171874
# Average score current 100 rounds: 0.12
#
#
# Play times: 165, Score: 0
# Epsilon: 0.15600000000005793
# Average loss: 27.15978495279948
# Average score current 100 rounds: 0.12
#
#
# Play times: 166, Score: 0
# Epsilon: 0.1514000000000578
# Average loss: 20.721995789071787
# Average score current 100 rounds: 0.12
#
#
# Play times: 167, Score: 1
# Epsilon: 0.14520000000005762
# Average loss: 21.24972471114128
# Average score current 100 rounds: 0.13
#
#
# Play times: 168, Score: 0
# Epsilon: 0.1416000000000575
# Average loss: 19.510609189669292
# Average score current 100 rounds: 0.13
#
#
# Play times: 169, Score: 1
# Epsilon: 0.1376000000000574
# Average loss: 14.290142130851745
# Average score current 100 rounds: 0.14
#
#
# Play times: 170, Score: 0
# Epsilon: 0.13580000000005735
# Average loss: 20.16932487487793
# Average score current 100 rounds: 0.14
#
#
# Play times: 171, Score: 0
# Epsilon: 0.1340000000000573
# Average loss: 22.936382240719265
# Average score current 100 rounds: 0.14
#
#
# Play times: 172, Score: 0
# Epsilon: 0.12820000000005713
# Average loss: 16.643100426114838
# Average score current 100 rounds: 0.14
#
#
# Play times: 173, Score: 0
# Epsilon: 0.12600000000005707
# Average loss: 16.320123889229514
# Average score current 100 rounds: 0.12
#
#
# Play times: 174, Score: 0
# Epsilon: 0.11240000000005668
# Average loss: 15.143234326558954
# Average score current 100 rounds: 0.12
#
#
# Play times: 175, Score: 0
# Epsilon: 0.11080000000005663
# Average loss: 7.848038673400879
# Average score current 100 rounds: 0.12
#
#
# Play times: 176, Score: 0
# Epsilon: 0.10440000000005645
# Average loss: 15.090210132300854
# Average score current 100 rounds: 0.12
#
#
# Play times: 177, Score: 2
# Epsilon: 0.09500000000005618
# Average loss: 19.813930815838752
# Average score current 100 rounds: 0.14
#
#
# Play times: 178, Score: 0
# Epsilon: 0.09340000000005613
# Average loss: 31.21379417181015
# Average score current 100 rounds: 0.14
#
#
# Play times: 179, Score: 0
# Epsilon: 0.08800000000005598
# Average loss: 25.628292383971036
# Average score current 100 rounds: 0.14
#
#
# Play times: 180, Score: 0
# Epsilon: 0.08700000000005595
# Average loss: 25.7048228263855
# Average score current 100 rounds: 0.14
#
#
# Play times: 181, Score: 1
# Epsilon: 0.08440000000005587
# Average loss: 11.870401382446289
# Average score current 100 rounds: 0.15
#
#
# Play times: 182, Score: 1
# Epsilon: 0.08260000000005582
# Average loss: 37.80497068829007
# Average score current 100 rounds: 0.16
#
#
# Play times: 183, Score: 1
# Epsilon: 0.07780000000005569
# Average loss: 21.478347778320312
# Average score current 100 rounds: 0.17
#
#
# Play times: 184, Score: 0
# Epsilon: 0.07600000000005563
# Average loss: 17.81536653306749
# Average score current 100 rounds: 0.17
#
#
# Play times: 185, Score: 0
# Epsilon: 0.06580000000005534
# Average loss: 17.60032991334504
# Average score current 100 rounds: 0.17
#
#
# Play times: 186, Score: 1
# Epsilon: 0.0644000000000553
# Average loss: 41.083478110177175
# Average score current 100 rounds: 0.18
#
#
# Play times: 187, Score: 0
# Epsilon: 0.052000000000055314
# Average loss: 18.28020819925493
# Average score current 100 rounds: 0.17
#
#
# Play times: 188, Score: 0
# Epsilon: 0.04740000000005534
# Average loss: 9.827553759450497
# Average score current 100 rounds: 0.17
#
#
# Play times: 189, Score: 0
# Epsilon: 0.04320000000005537
# Average loss: 17.27562279928298
# Average score current 100 rounds: 0.17
#
#
# Play times: 190, Score: 0
# Epsilon: 0.03400000000005542
# Average loss: 10.330786912337594
# Average score current 100 rounds: 0.16
#
#
# Play times: 191, Score: 0
# Epsilon: 0.030600000000055444
# Average loss: 14.735199521569644
# Average score current 100 rounds: 0.16
#
#
# Play times: 192, Score: 0
# Epsilon: 0.02640000000005547
# Average loss: 12.703986281440372
# Average score current 100 rounds: 0.16
#
#
# Play times: 193, Score: 0
# Epsilon: 0.007200000000055514
# Average loss: 13.580821240941683
# Average score current 100 rounds: 0.16
#
#
# Play times: 194, Score: 0
# Epsilon: 0
# Average loss: 24.85178084471791
# Average score current 100 rounds: 0.16
#
#
# Play times: 195, Score: 1
# Epsilon: 0
# Average loss: 30.331988209944505
# Average score current 100 rounds: 0.17
#
#
# Play times: 196, Score: 2
# Epsilon: 0
# Average loss: 54.693662786016276
# Average score current 100 rounds: 0.19
#
#
# Play times: 197, Score: 0
# Epsilon: 0
# Average loss: 36.256223149597645
# Average score current 100 rounds: 0.19
#
#
# Play times: 198, Score: 1
# Epsilon: 0
# Average loss: 39.50881228912836
# Average score current 100 rounds: 0.2
#
#
# Play times: 199, Score: 0
# Epsilon: 0
# Average loss: 38.224664464592934
# Average score current 100 rounds: 0.2
#
#
# Model saved to /content/drive/My Drive/newSnakeRL/model/weights/linear_dqn_model.pth
# Feel free to press Ctrl+C to terminate the program or close the window
# Play times: 200, Score: 1
# Epsilon: 0
# Average loss: 69.04363525264404
# Average score current 100 rounds: 0.21
#
#
# Play times: 201, Score: 14
# Epsilon: 0
# Average loss: 27.675343904104622
# Average score current 100 rounds: 0.34
#
#
# Play times: 202, Score: 0
# Epsilon: 0
# Average loss: 11.991159190734228
# Average score current 100 rounds: 0.34
#
#
# Play times: 203, Score: 1
# Epsilon: 0
# Average loss: 34.66877381051524
# Average score current 100 rounds: 0.35
#
#
# Play times: 204, Score: 0
# Epsilon: 0
# Average loss: 23.211220579842728
# Average score current 100 rounds: 0.35
#
#
# Play times: 205, Score: 8
# Epsilon: 0
# Average loss: 46.46480064451202
# Average score current 100 rounds: 0.43
#
#
# Play times: 206, Score: 2
# Epsilon: 0
# Average loss: 8.347926846618861
# Average score current 100 rounds: 0.45
#
#
# Play times: 207, Score: 1
# Epsilon: 0
# Average loss: 22.135875230326373
# Average score current 100 rounds: 0.46
#
#
# Play times: 208, Score: 2
# Epsilon: 0
# Average loss: 23.86852641584139
# Average score current 100 rounds: 0.48
#
#
# Play times: 209, Score: 1
# Epsilon: 0
# Average loss: 23.98630428130244
# Average score current 100 rounds: 0.49
#
#
# Play times: 210, Score: 12
# Epsilon: 0
# Average loss: 14.72728867261336
# Average score current 100 rounds: 0.61
#
#
# Play times: 211, Score: 0
# Epsilon: 0
# Average loss: 5.362625603823318
# Average score current 100 rounds: 0.61
#
#
# Play times: 212, Score: 0
# Epsilon: 0
# Average loss: 12.562700166677436
# Average score current 100 rounds: 0.61
#
#
# Play times: 213, Score: 2
# Epsilon: 0
# Average loss: 43.68783330554898
# Average score current 100 rounds: 0.63
#
#
# Play times: 214, Score: 2
# Epsilon: 0
# Average loss: 43.94349188217218
# Average score current 100 rounds: 0.65
#
#
# Play times: 215, Score: 0
# Epsilon: 0
# Average loss: 10.909023077537617
# Average score current 100 rounds: 0.65
#
#
# Play times: 216, Score: 11
# Epsilon: 0
# Average loss: 15.806286801762322
# Average score current 100 rounds: 0.76
#
#
# Play times: 217, Score: 1
# Epsilon: 0
# Average loss: 10.414824255939687
# Average score current 100 rounds: 0.77
#
#
# Play times: 218, Score: 29
# Epsilon: 0
# Average loss: 10.117598376821363
# Average score current 100 rounds: 1.06
#
#
# Play times: 219, Score: 0
# Epsilon: 0
# Average loss: 14.361459789176783
# Average score current 100 rounds: 1.06
#
#
# Play times: 220, Score: 0
# Epsilon: 0
# Average loss: 35.30535148332516
# Average score current 100 rounds: 1.06
#
#
# Play times: 221, Score: 2
# Epsilon: 0
# Average loss: 61.401042704941126
# Average score current 100 rounds: 1.08
#
#
# Play times: 222, Score: 0
# Epsilon: 0
# Average loss: 37.24447070310513
# Average score current 100 rounds: 1.08
#
#
# Play times: 223, Score: 0
# Epsilon: 0
# Average loss: 50.604770501454674
# Average score current 100 rounds: 1.08
#
#
# Play times: 224, Score: 4
# Epsilon: 0
# Average loss: 54.37447515058746
# Average score current 100 rounds: 1.12
#
#
# Play times: 225, Score: 0
# Epsilon: 0
# Average loss: 34.747181100943656
# Average score current 100 rounds: 1.12
#
#
# Play times: 226, Score: 1
# Epsilon: 0
# Average loss: 41.555015085348444
# Average score current 100 rounds: 1.13
#
#
# Play times: 227, Score: 34
# Epsilon: 0
# Average loss: 13.537254384308982
# Average score current 100 rounds: 1.47
#
#
# Play times: 228, Score: 0
# Epsilon: 0
# Average loss: 20.414720942576725
# Average score current 100 rounds: 1.47
#
#
# Play times: 229, Score: 0
# Epsilon: 0
# Average loss: 21.317858236531418
# Average score current 100 rounds: 1.47
#
#
# Play times: 230, Score: 29
# Epsilon: 0
# Average loss: 17.752643366410084
# Average score current 100 rounds: 1.76
#
#
# Play times: 231, Score: 17
# Epsilon: 0
# Average loss: 15.04880222188575
# Average score current 100 rounds: 1.92
#
#
# Play times: 232, Score: 49
# Epsilon: 0
# Average loss: 8.343209833217974
# Average score current 100 rounds: 2.4
#
#
# Play times: 233, Score: 2
# Epsilon: 0
# Average loss: 21.105377000457835
# Average score current 100 rounds: 2.42
#
#
# Play times: 234, Score: 0
# Epsilon: 0
# Average loss: 35.51681370587693
# Average score current 100 rounds: 2.42
#
#
# Play times: 235, Score: 32
# Epsilon: 0
# Average loss: 13.148657991367903
# Average score current 100 rounds: 2.72
#
#
# Play times: 236, Score: 0
# Epsilon: 0
# Average loss: 15.192089257140955
# Average score current 100 rounds: 2.71
#
#
# Play times: 237, Score: 20
# Epsilon: 0
# Average loss: 31.540127785798642
# Average score current 100 rounds: 2.91
#
#
# Play times: 238, Score: 56
# Epsilon: 0
# Average loss: 10.30357542481269
# Average score current 100 rounds: 3.47
#
#
# Play times: 239, Score: 5
# Epsilon: 0
# Average loss: 30.608443021774292
# Average score current 100 rounds: 3.52
#
#
# Play times: 240, Score: 45
# Epsilon: 0
# Average loss: 17.289280944969505
# Average score current 100 rounds: 3.97
#
#
# Play times: 241, Score: 10
# Epsilon: 0
# Average loss: 20.06238007212198
# Average score current 100 rounds: 4.07
#
#
# Play times: 242, Score: 33
# Epsilon: 0
# Average loss: 11.138533627474967
# Average score current 100 rounds: 4.4
#
#
# Play times: 243, Score: 0
# Epsilon: 0
# Average loss: 12.70276437486921
# Average score current 100 rounds: 4.4
#
#
# Play times: 244, Score: 0
# Epsilon: 0
# Average loss: 10.656880557537079
# Average score current 100 rounds: 4.4
#
#
# Play times: 245, Score: 5
# Epsilon: 0
# Average loss: 13.754029354692875
# Average score current 100 rounds: 4.45
#
#
# Play times: 246, Score: 2
# Epsilon: 0
# Average loss: 10.739429818287055
# Average score current 100 rounds: 4.47
#
#
# Play times: 247, Score: 1
# Epsilon: 0
# Average loss: 34.56045012176037
# Average score current 100 rounds: 4.48
#
#
# Play times: 248, Score: 0
# Epsilon: 0
# Average loss: 41.08799015109738
# Average score current 100 rounds: 4.48
#
#
# Play times: 249, Score: 4
# Epsilon: 0
# Average loss: 36.75358202609305
# Average score current 100 rounds: 4.52
#
#
# Model saved to /content/drive/My Drive/newSnakeRL/model/weights/linear_dqn_model.pth
# Feel free to press Ctrl+C to terminate the program or close the window
# Play times: 250, Score: 47
# Epsilon: 0
# Average loss: 11.780258417260459
# Average score current 100 rounds: 4.99
#
#
# Play times: 251, Score: 35
# Epsilon: 0
# Average loss: 14.353165230803581
# Average score current 100 rounds: 5.34
#
#
# Play times: 252, Score: 55
# Epsilon: 0
# Average loss: 9.178719652060883
# Average score current 100 rounds: 5.89
#
#
# Play times: 253, Score: 0
# Epsilon: 0
# Average loss: 35.00558771813909
# Average score current 100 rounds: 5.89
#
#
# Play times: 254, Score: 1
# Epsilon: 0
# Average loss: 34.38160559839132
# Average score current 100 rounds: 5.9
#
#
# Play times: 255, Score: 2
# Epsilon: 0
# Average loss: 34.239381605765494
# Average score current 100 rounds: 5.91
#
#
# Play times: 256, Score: 1
# Epsilon: 0
# Average loss: 37.24129940489776
# Average score current 100 rounds: 5.92
#
#
# Play times: 257, Score: 38
# Epsilon: 0
# Average loss: 21.12103251422441
# Average score current 100 rounds: 6.3
#
#
# Play times: 258, Score: 0
# Epsilon: 0
# Average loss: 23.810953023533028
# Average score current 100 rounds: 6.29
#
#
# Play times: 259, Score: 12
# Epsilon: 0
# Average loss: 43.232000891938966
# Average score current 100 rounds: 6.41
#
#
# Play times: 260, Score: 5
# Epsilon: 0
# Average loss: 27.975382629307834
# Average score current 100 rounds: 6.46
#
#
# Play times: 261, Score: 23
# Epsilon: 0
# Average loss: 18.738565526821816
# Average score current 100 rounds: 6.69
#
#
# Play times: 262, Score: 3
# Epsilon: 0
# Average loss: 12.43582091146848
# Average score current 100 rounds: 6.72
#
#
# Play times: 263, Score: 71
# Epsilon: 0
# Average loss: 19.04127789553495
# Average score current 100 rounds: 7.43
#
#
# Play times: 264, Score: 1
# Epsilon: 0
# Average loss: 31.495928683647744
# Average score current 100 rounds: 7.44
#
#
# Play times: 265, Score: 0
# Epsilon: 0
# Average loss: 47.515951119747356
# Average score current 100 rounds: 7.44
#
#
# Play times: 266, Score: 0
# Epsilon: 0
# Average loss: 52.48840740074714
# Average score current 100 rounds: 7.44
#
#
# Play times: 267, Score: 0
# Epsilon: 0
# Average loss: 59.23365228623152
# Average score current 100 rounds: 7.43
#
#
# Play times: 268, Score: 3
# Epsilon: 0
# Average loss: 87.053340220705
# Average score current 100 rounds: 7.46
#
#
# Play times: 269, Score: 2
# Epsilon: 0
# Average loss: 86.11581290647182
# Average score current 100 rounds: 7.47
#
#
# Play times: 270, Score: 5
# Epsilon: 0
# Average loss: 27.825117303900523
# Average score current 100 rounds: 7.52
#
#
# Play times: 271, Score: 4
# Epsilon: 0
# Average loss: 49.992303716547696
# Average score current 100 rounds: 7.56
#
#
# Play times: 272, Score: 35
# Epsilon: 0
# Average loss: 14.376040813324575
# Average score current 100 rounds: 7.91
#
#
# Play times: 273, Score: 71
# Epsilon: 0
# Average loss: 16.753749000798674
# Average score current 100 rounds: 8.62
#
#
# Play times: 274, Score: 5
# Epsilon: 0
# Average loss: 30.832297194356155
# Average score current 100 rounds: 8.67
#
#
# Play times: 275, Score: 53
# Epsilon: 0
# Average loss: 18.034376143134487
# Average score current 100 rounds: 9.2
#
#
# Play times: 276, Score: 44
# Epsilon: 0
# Average loss: 20.526509418354166
# Average score current 100 rounds: 9.64
#
#
# Play times: 277, Score: 32
# Epsilon: 0
# Average loss: 10.991817213472773
# Average score current 100 rounds: 9.94
#
#
# Play times: 278, Score: 57
# Epsilon: 0
# Average loss: 11.016601832846264
# Average score current 100 rounds: 10.51
#
#
# Play times: 279, Score: 38
# Epsilon: 0
# Average loss: 17.397403039869648
# Average score current 100 rounds: 10.89
#
#
# Play times: 280, Score: 28
# Epsilon: 0
# Average loss: 15.684596850991793
# Average score current 100 rounds: 11.17
#
#
# Play times: 281, Score: 1
# Epsilon: 0
# Average loss: 17.000756872422766
# Average score current 100 rounds: 11.17
#
#
# Play times: 282, Score: 35
# Epsilon: 0
# Average loss: 25.26354347804202
# Average score current 100 rounds: 11.51
#
#
# Play times: 283, Score: 52
# Epsilon: 0
# Average loss: 18.070457427238853
# Average score current 100 rounds: 12.02
#
#
# Play times: 284, Score: 50
# Epsilon: 0
# Average loss: 15.346314722601372
# Average score current 100 rounds: 12.52
#
#
# Play times: 285, Score: 16
# Epsilon: 0
# Average loss: 33.209699995815754
# Average score current 100 rounds: 12.68
#
#
# Play times: 286, Score: 1
# Epsilon: 0
# Average loss: 25.749472209385463
# Average score current 100 rounds: 12.68
#
#
# Play times: 287, Score: 54
# Epsilon: 0
# Average loss: 33.87476898042721
# Average score current 100 rounds: 13.22
#
#
# Play times: 288, Score: 43
# Epsilon: 0
# Average loss: 19.93269942746876
# Average score current 100 rounds: 13.65
#
#
# Play times: 289, Score: 55
# Epsilon: 0
# Average loss: 23.640295487137163
# Average score current 100 rounds: 14.2
#
#
# Play times: 290, Score: 41
# Epsilon: 0
# Average loss: 27.05197377767875
# Average score current 100 rounds: 14.61
#
#
# Play times: 291, Score: 0
# Epsilon: 0
# Average loss: 30.98030984898408
# Average score current 100 rounds: 14.61
#
#
# Play times: 292, Score: 13
# Epsilon: 0
# Average loss: 70.99103978929065
# Average score current 100 rounds: 14.74
#
#
# Play times: 293, Score: 9
# Epsilon: 0
# Average loss: 61.53740303005491
# Average score current 100 rounds: 14.83
#
#
# Play times: 294, Score: 61
# Epsilon: 0
# Average loss: 28.42523247108341
# Average score current 100 rounds: 15.44
#
#
# Play times: 295, Score: 7
# Epsilon: 0
# Average loss: 20.139596133336532
# Average score current 100 rounds: 15.5
#
#
# Play times: 296, Score: 46
# Epsilon: 0
# Average loss: 25.23133926211354
# Average score current 100 rounds: 15.94
#
#
# Play times: 297, Score: 55
# Epsilon: 0
# Average loss: 14.839122491334056
# Average score current 100 rounds: 16.49
#
#
# Play times: 298, Score: 53
# Epsilon: 0
# Average loss: 25.726816732906602
# Average score current 100 rounds: 17.01
#
#
# Play times: 299, Score: 59
# Epsilon: 0
# Average loss: 30.405047682510027
# Average score current 100 rounds: 17.6
#
#
# Model saved to /content/drive/My Drive/newSnakeRL/model/weights/linear_dqn_model.pth
# Feel free to press Ctrl+C to terminate the program or close the window
# Play times: 300, Score: 15
# Epsilon: 0
# Average loss: 40.5594657088771
# Average score current 100 rounds: 17.74
#
#
# Play times: 301, Score: 49
# Epsilon: 0
# Average loss: 32.327251770091024
# Average score current 100 rounds: 18.09
#
#
# Play times: 302, Score: 18
# Epsilon: 0
# Average loss: 32.56821321775127
# Average score current 100 rounds: 18.27
#
#
# Play times: 303, Score: 38
# Epsilon: 0
# Average loss: 33.07535980102864
# Average score current 100 rounds: 18.64
#
#
# Play times: 304, Score: 51
# Epsilon: 0
# Average loss: 27.626728532232086
# Average score current 100 rounds: 19.15
#
#
# Play times: 305, Score: 35
# Epsilon: 0
# Average loss: 35.17882624509042
# Average score current 100 rounds: 19.42
#
#
# Play times: 306, Score: 49
# Epsilon: 0
# Average loss: 37.98361811103663
# Average score current 100 rounds: 19.89
#
#
# Play times: 307, Score: 53
# Epsilon: 0
# Average loss: 38.17838694190337
# Average score current 100 rounds: 20.41
#
#
# Play times: 308, Score: 33
# Epsilon: 0
# Average loss: 29.8324292052564
# Average score current 100 rounds: 20.72
#
#
# Play times: 309, Score: 58
# Epsilon: 0
# Average loss: 26.257208735443825
# Average score current 100 rounds: 21.29
#
#
# Play times: 310, Score: 70
# Epsilon: 0
# Average loss: 45.08999755173326
# Average score current 100 rounds: 21.87
#
#
# Play times: 311, Score: 56
# Epsilon: 0
# Average loss: 40.887230499054205
# Average score current 100 rounds: 22.43
#
#
# Play times: 312, Score: 69
# Epsilon: 0
# Average loss: 37.883723577246606
# Average score current 100 rounds: 23.12
#
#
# Play times: 313, Score: 0
# Epsilon: 0
# Average loss: 45.43898315429688
# Average score current 100 rounds: 23.1
#
#
# Play times: 314, Score: 0
# Epsilon: 0
# Average loss: 55.849784504283555
# Average score current 100 rounds: 23.08
#
#
# Play times: 315, Score: 70
# Epsilon: 0
# Average loss: 65.12610689708552
# Average score current 100 rounds: 23.78
#
#
# Play times: 316, Score: 50
# Epsilon: 0
# Average loss: 39.60256891894194
# Average score current 100 rounds: 24.17
#
#
# Play times: 317, Score: 84
# Epsilon: 0
# Average loss: 44.2485072384974
# Average score current 100 rounds: 25.0
#
#
# Play times: 318, Score: 58
# Epsilon: 0
# Average loss: 55.15057322943854
# Average score current 100 rounds: 25.29
#
#
# Play times: 319, Score: 54
# Epsilon: 0
# Average loss: 22.071058887853088
# Average score current 100 rounds: 25.83
#
#
# Play times: 320, Score: 69
# Epsilon: 0
# Average loss: 34.60562501365583
# Average score current 100 rounds: 26.52
#
#
# Play times: 321, Score: 85
# Epsilon: 0
# Average loss: 61.36935326261649
# Average score current 100 rounds: 27.35
#
#
# Play times: 322, Score: 68
# Epsilon: 0
# Average loss: 57.2274589700425
# Average score current 100 rounds: 28.03
#
#
# Play times: 323, Score: 69
# Epsilon: 0
# Average loss: 33.114607036049165
# Average score current 100 rounds: 28.72
#
#
# Play times: 324, Score: 53
# Epsilon: 0
# Average loss: 42.32939329454976
# Average score current 100 rounds: 29.21
#
#
# Play times: 325, Score: 65
# Epsilon: 0
# Average loss: 43.885375096971394
# Average score current 100 rounds: 29.86
#
#
# Play times: 326, Score: 87
# Epsilon: 0
# Average loss: 37.54091448387199
# Average score current 100 rounds: 30.72
#
#
# Play times: 327, Score: 74
# Epsilon: 0
# Average loss: 50.150270786838256
# Average score current 100 rounds: 31.12
#
#
# Play times: 328, Score: 69
# Epsilon: 0
# Average loss: 38.238734678649905
# Average score current 100 rounds: 31.81
#
#
# Play times: 329, Score: 63
# Epsilon: 0
# Average loss: 39.95732327894731
# Average score current 100 rounds: 32.44
#
#
# Play times: 330, Score: 73
# Epsilon: 0
# Average loss: 37.70884721653134
# Average score current 100 rounds: 32.88
#
#
# Play times: 331, Score: 14
# Epsilon: 0
# Average loss: 26.81243953677271
# Average score current 100 rounds: 32.85
#
#
# Play times: 332, Score: 22
# Epsilon: 0
# Average loss: 29.244782987343836
# Average score current 100 rounds: 32.58
#
#
# Play times: 333, Score: 19
# Epsilon: 0
# Average loss: 44.22735278837143
# Average score current 100 rounds: 32.75
#
#
# Play times: 334, Score: 70
# Epsilon: 0
# Average loss: 33.543574256829096
# Average score current 100 rounds: 33.45
#
#
# Play times: 335, Score: 69
# Epsilon: 0
# Average loss: 37.11065519062954
# Average score current 100 rounds: 33.82
#
#
# Play times: 336, Score: 72
# Epsilon: 0
# Average loss: 36.970794258994616
# Average score current 100 rounds: 34.54
#
#
# Play times: 337, Score: 58
# Epsilon: 0
# Average loss: 33.95477960716864
# Average score current 100 rounds: 34.92
#
#
# Play times: 338, Score: 44
# Epsilon: 0
# Average loss: 34.89542806110685
# Average score current 100 rounds: 34.8
#
#
# Play times: 339, Score: 69
# Epsilon: 0
# Average loss: 39.73564534492681
# Average score current 100 rounds: 35.44
#
#
# Play times: 340, Score: 74
# Epsilon: 0
# Average loss: 56.72965819971777
# Average score current 100 rounds: 35.73
#
#
# Play times: 341, Score: 53
# Epsilon: 0
# Average loss: 71.89584183429
# Average score current 100 rounds: 36.16
#
#
# Play times: 342, Score: 77
# Epsilon: 0
# Average loss: 40.51721038292946
# Average score current 100 rounds: 36.6
#
#
# Play times: 343, Score: 52
# Epsilon: 0
# Average loss: 66.43867567965859
# Average score current 100 rounds: 37.12
#
#
# Play times: 344, Score: 55
# Epsilon: 0
# Average loss: 49.31744811269972
# Average score current 100 rounds: 37.67
#
#
# Play times: 345, Score: 56
# Epsilon: 0
# Average loss: 57.241079248407836
# Average score current 100 rounds: 38.18
#
#
# Play times: 346, Score: 67
# Epsilon: 0
# Average loss: 35.69584784492353
# Average score current 100 rounds: 38.83
#
#
# Play times: 347, Score: 60
# Epsilon: 0
# Average loss: 32.738227459494134
# Average score current 100 rounds: 39.42
#
#
# Play times: 348, Score: 13
# Epsilon: 0
# Average loss: 37.58831957274792
# Average score current 100 rounds: 39.55
#
#
# Play times: 349, Score: 7
# Epsilon: 0
# Average loss: 52.45087767404223
# Average score current 100 rounds: 39.58
#
#
# Model saved to /content/drive/My Drive/newSnakeRL/model/weights/linear_dqn_model.pth
# Feel free to press Ctrl+C to terminate the program or close the window
# Play times: 350, Score: 74
# Epsilon: 0
# Average loss: 43.844674687888755
# Average score current 100 rounds: 39.85
#
#
# Play times: 351, Score: 48
# Epsilon: 0
# Average loss: 86.45244596559081
# Average score current 100 rounds: 39.98
#
#
# Play times: 352, Score: 73
# Epsilon: 0
# Average loss: 36.554759425139494
# Average score current 100 rounds: 40.16
#
#
# Play times: 353, Score: 66
# Epsilon: 0
# Average loss: 53.14834994260769
# Average score current 100 rounds: 40.82
#
#
# Play times: 354, Score: 65
# Epsilon: 0
# Average loss: 45.090858202997644
# Average score current 100 rounds: 41.46
#
#
# Play times: 355, Score: 64
# Epsilon: 0
# Average loss: 52.63150935516952
# Average score current 100 rounds: 42.08
#
#
# Play times: 356, Score: 80
# Epsilon: 0
# Average loss: 38.66798700744567
# Average score current 100 rounds: 42.87
#
#
# Play times: 357, Score: 86
# Epsilon: 0
# Average loss: 68.72375963369392
# Average score current 100 rounds: 43.35
#
#
# Play times: 358, Score: 74
# Epsilon: 0
# Average loss: 55.38295924039332
# Average score current 100 rounds: 44.09
#
#
# Play times: 359, Score: 43
# Epsilon: 0
# Average loss: 45.08485076987678
# Average score current 100 rounds: 44.4
#
#
# Play times: 360, Score: 66
# Epsilon: 0
# Average loss: 36.905836234940054
# Average score current 100 rounds: 45.01
#
#
# Play times: 361, Score: 89
# Epsilon: 0
# Average loss: 48.21068465987533
# Average score current 100 rounds: 45.67
